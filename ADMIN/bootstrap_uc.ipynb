# %%
# %sql
-- Create catalog if missing
CREATE CATALOG IF NOT EXISTS :catalog_name:;

-- Switch to catalog
USE CATALOG :catalog_name:;

-- Create schema for pipeline output if missing
CREATE SCHEMA IF NOT EXISTS :schema_name:;
